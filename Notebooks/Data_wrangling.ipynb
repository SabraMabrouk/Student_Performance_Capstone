# %% [markdown]
# # <center>Data Wrangling</center>

# %% [markdown]
# ## Import packages

# %%
import requests
import json
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Load the data
# We first loaded the mata data of the dataset from the API of <a href='https://archive.ics.uci.edu/dataset/320/student+performance'>UCI Machine Learning repository</a>

# %%
id=320
api_url = 'https://archive.ics.uci.edu/api/dataset?id=' + str(id) 
resp = requests.get(api_url)
json_data = resp.json()
json_data['data']['variables']
# Out:
# [{'name': 'school',
#   'role': 'Feature',
#   'type': 'Categorical',
#   'demographic': None,
#   'description': "student's school (binary: 'GP' - Gabriel Pereira or 'MS' - Mousinho da Silveira)",
#   'units': None,
#   'missing_values': 'no'},
#  {'name': 'sex',
#   'role': 'Feature',
#   'type': 'Binary',
#   'demographic': 'Sex',
#   'description': "student's sex (binary: 'F' - female or 'M' - male)",
#   'units': None,
#   'missing_values': 'no'},
#  {'name': 'age',
#   'role': 'Feature',
#   'type': 'Integer',
#   'demographic': 'Age',
#   'description': "student's age (numeric: from 15 to 22)",
#   'units': None,
#   'missing_values': 'no'},
#  {'name': 'address',
#   'role': 'Feature',
#   'type': 'Categorical',
#   'demographic': None,
#   'description': "student's home address type (binary: 'U' - urban or 'R' - rural)",
#   'units': None,
#   'missing_values': 'no'},
#  {'name': 'famsize',
#   'role': 'Feature',
#   'type': 'Categorical',
#   'demographic': 'Other',
#   'description': "family size (binary: 'LE3' - less or equal to 3 or 'GT3' - greater than 3)",
#   'units': None,
#   'missing_values': 'no'},
#  {'name': 'Pstatus',
#   'role': 'Feature',
#   'type': 'Categorical',
#   'demographic': 'Other',
#   'description': "parent's cohabitation status (binary: 'T' - living together or 'A' - apart)",
#   'units': None,
#   'missing_values': 'no'},
#  {'name': 'Medu',
#   'role': 'Feature',
#   'type': 'Integer',
#   'demographic': 'Education Level',
#   'description': "mother's education (numeric: 0 - none,  1 - primary education (4th grade), 2 - 5th to 9th grade, 3 - secondary education or 4 - higher education)",
#   'units': None,
#   'missing_values': 'no'},
#  {'name': 'Fedu',
#   'role': 'Feature',
#   'type': 'Integer',
#   'demographic': 'Education Level',
#   'description': "father's education (numeric: 0 - none,  1 - primary education (4th grade), 2 â€“ 5th to 9th grade, 3 â€“ secondary education or 4 â€“ higher education)",
#   'units': None,
#   'missing_values': 'no'},
#  {'name': 'Mjob',
#   'role': 'Feature',
#   'type': 'Categorical',
#   'demographic': 'Occupation',
#   'description': "mother's job (nominal: 'teacher', 'health' care related, civil 'services' (e.g. administrative or police), 'at_home' or 'other')",
#   'units': None,
#   'missing_values': 'no'},
#  {'name': 'Fjob',
#   'role': 'Feature',
#   'type': 'Categorical',
#   'demographic': 'Occupation',
#   'description': "father's job (nominal: 'teacher', 'health' care related, civil 'services' (e.g. administrative or police), 'at_home' or 'other')",
#   'units': None,
#   'missing_values': 'no'},
#  {'name': 'reason',
#   'role': 'Feature',
#   'type': 'Categorical',
#   'demographic': None,
#   'description': "reason to choose this school (nominal: close to 'home', school 'reputation', 'course' preference or 'other')",
#   'units': None,
#   'missing_values': 'no'},
#  {'name': 'guardian',
#   'role': 'Feature',
#   'type': 'Categorical',
#   'demographic': None,
#   'description': "student's guardian (nominal: 'mother', 'father' or 'other')",
#   'units': None,
#   'missing_values': 'no'},
#  {'name': 'traveltime',
#   'role': 'Feature',
#   'type': 'Integer',
#   'demographic': None,
#   'description': 'home to school travel time (numeric: 1 - <15 min., 2 - 15 to 30 min., 3 - 30 min. to 1 hour, or 4 - >1 hour)',
#   'units': None,
#   'missing_values': 'no'},
#  {'name': 'studytime',
#   'role': 'Feature',
#   'type': 'Integer',
#   'demographic': None,
#   'description': 'weekly study time (numeric: 1 - <2 hours, 2 - 2 to 5 hours, 3 - 5 to 10 hours, or 4 - >10 hours)',
#   'units': None,
#   'missing_values': 'no'},
#  {'name': 'failures',
#   'role': 'Feature',
#   'type': 'Integer',
#   'demographic': None,
#   'description': 'number of past class failures (numeric: n if 1<=n<3, else 4)',
#   'units': None,
#   'missing_values': 'no'},
#  {'name': 'schoolsup',
#   'role': 'Feature',
#   'type': 'Binary',
#   'demographic': None,
#   'description': 'extra educational support (binary: yes or no)',
#   'units': None,
#   'missing_values': 'no'},
#  {'name': 'famsup',
#   'role': 'Feature',
#   'type': 'Binary',
#   'demographic': None,
#   'description': 'family educational support (binary: yes or no)',
#   'units': None,
#   'missing_values': 'no'},
#  {'name': 'paid',
#   'role': 'Feature',
#   'type': 'Binary',
#   'demographic': None,
#   'description': 'extra paid classes within the course subject (Math or Portuguese) (binary: yes or no)',
#   'units': None,
#   'missing_values': 'no'},
#  {'name': 'activities',
#   'role': 'Feature',
#   'type': 'Binary',
#   'demographic': None,
#   'description': 'extra-curricular activities (binary: yes or no)',
#   'units': None,
#   'missing_values': 'no'},
#  {'name': 'nursery',
#   'role': 'Feature',
#   'type': 'Binary',
#   'demographic': None,
#   'description': 'attended nursery school (binary: yes or no)',
#   'units': None,
#   'missing_values': 'no'},
#  {'name': 'higher',
#   'role': 'Feature',
#   'type': 'Binary',
#   'demographic': None,
#   'description': 'wants to take higher education (binary: yes or no)',
#   'units': None,
#   'missing_values': 'no'},
#  {'name': 'internet',
#   'role': 'Feature',
#   'type': 'Binary',
#   'demographic': None,
#   'description': 'Internet access at home (binary: yes or no)',
#   'units': None,
#   'missing_values': 'no'},
#  {'name': 'romantic',
#   'role': 'Feature',
#   'type': 'Binary',
#   'demographic': None,
#   'description': 'with a romantic relationship (binary: yes or no)',
#   'units': None,
#   'missing_values': 'no'},
#  {'name': 'famrel',
#   'role': 'Feature',
#   'type': 'Integer',
#   'demographic': None,
#   'description': 'quality of family relationships (numeric: from 1 - very bad to 5 - excellent)',
#   'units': None,
#   'missing_values': 'no'},
#  {'name': 'freetime',
#   'role': 'Feature',
#   'type': 'Integer',
#   'demographic': None,
#   'description': 'free time after school (numeric: from 1 - very low to 5 - very high)',
#   'units': None,
#   'missing_values': 'no'},
#  {'name': 'goout',
#   'role': 'Feature',
#   'type': 'Integer',
#   'demographic': None,
#   'description': 'going out with friends (numeric: from 1 - very low to 5 - very high)',
#   'units': None,
#   'missing_values': 'no'},
#  {'name': 'Dalc',
#   'role': 'Feature',
#   'type': 'Integer',
#   'demographic': None,
#   'description': 'workday alcohol consumption (numeric: from 1 - very low to 5 - very high)',
#   'units': None,
#   'missing_values': 'no'},
#  {'name': 'Walc',
#   'role': 'Feature',
#   'type': 'Integer',
#   'demographic': None,
#   'description': 'weekend alcohol consumption (numeric: from 1 - very low to 5 - very high)',
#   'units': None,
#   'missing_values': 'no'},
#  {'name': 'health',
#   'role': 'Feature',
#   'type': 'Integer',
#   'demographic': None,
#   'description': 'current health status (numeric: from 1 - very bad to 5 - very good)',
#   'units': None,
#   'missing_values': 'no'},
#  {'name': 'absences',
#   'role': 'Feature',
#   'type': 'Integer',
#   'demographic': None,
#   'description': 'number of school absences (numeric: from 0 to 93)',
#   'units': None,
#   'missing_values': 'no'},
#  {'name': 'G1',
#   'role': 'Target',
#   'type': 'Categorical',
#   'demographic': None,
#   'description': 'first period grade (numeric: from 0 to 20)',
#   'units': None,
#   'missing_values': 'no'},
#  {'name': 'G2',
#   'role': 'Target',
#   'type': 'Categorical',
#   'demographic': None,
#   'description': 'second period grade (numeric: from 0 to 20)',
#   'units': None,
#   'missing_values': 'no'},
#  {'name': 'G3',
#   'role': 'Target',
#   'type': 'Integer',
#   'demographic': None,
#   'description': 'final grade (numeric: from 0 to 20, output target)',
#   'units': None,
#   'missing_values': 'no'}]

# %% [markdown]
# Then, we load data from two csv files containing data for the math and the portuguese language courses.

# %%
# load student performance in Math course
df_math = pd.read_csv('./data/student-mat.csv',sep=';')

# load student performance in Portuguese language course
df_port = pd.read_csv('./data/student-por.csv',sep=';')

# %% [markdown]
# We next concatenate the two DataFrames, we added a column for the course

# %%
df_math['course'] = 'math'
df_port['course'] = 'portuguese'
df_student = pd.concat([df_math,df_port],ignore_index=True)
print('# students in math course',df_math.shape)
print('# students in portuguese course',df_port.shape)
df_student
# Out:
# # students in math course (395, 34)
# # students in portuguese course (649, 34)
#      school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0        GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1        GP   F   17       U     GT3       T     1     1   at_home     other
# 2        GP   F   15       U     LE3       T     1     1   at_home     other
# 3        GP   F   15       U     GT3       T     4     2    health  services
# 4        GP   F   16       U     GT3       T     3     3     other     other
# ...     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 1039     MS   F   19       R     GT3       T     2     3  services     other
# 1040     MS   F   18       U     LE3       T     3     1   teacher  services
# 1041     MS   F   18       U     GT3       T     1     1     other     other
# 1042     MS   M   17       U     LE3       T     3     1  services  services
# 1043     MS   M   18       R     LE3       T     3     2  services     other
#
#       ... freetime goout  Dalc  Walc  health absences  G1  G2  G3      course
# 0     ...        3     4     1     1       3        6   5   6   6        math
# 1     ...        3     3     1     1       3        4   5   5   6        math
# 2     ...        3     2     2     3       3       10   7   8  10        math
# 3     ...        2     2     1     1       5        2  15  14  15        math
# 4     ...        3     2     1     2       5        4   6  10  10        math
# ...   ...      ...   ...   ...   ...     ...      ...  ..  ..  ..         ...
# 1039  ...        4     2     1     2       5        4  10  11  10  portuguese
# 1040  ...        3     4     1     1       1        4  15  15  16  portuguese
# 1041  ...        1     1     1     1       5        6  11  12   9  portuguese
# 1042  ...        4     5     3     4       2        6  10  10  10  portuguese
# 1043  ...        4     1     3     4       5        4  10  11  11  portuguese
#
# [1044 rows x 34 columns]

# %% [markdown]
# We call the info method to see a summary of the data

# %%
df_student.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1044 entries, 0 to 1043
# Data columns (total 34 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      1044 non-null   object
#  1   sex         1044 non-null   object
#  2   age         1044 non-null   int64
#  3   address     1044 non-null   object
#  4   famsize     1044 non-null   object
#  5   Pstatus     1044 non-null   object
#  6   Medu        1044 non-null   int64
#  7   Fedu        1044 non-null   int64
#  8   Mjob        1044 non-null   object
#  9   Fjob        1044 non-null   object
#  10  reason      1044 non-null   object
#  11  guardian    1044 non-null   object
#  12  traveltime  1044 non-null   int64
#  13  studytime   1044 non-null   int64
#  14  failures    1044 non-null   int64
#  15  schoolsup   1044 non-null   object
#  16  famsup      1044 non-null   object
#  17  paid        1044 non-null   object
#  18  activities  1044 non-null   object
#  19  nursery     1044 non-null   object
#  20  higher      1044 non-null   object
#  21  internet    1044 non-null   object
#  22  romantic    1044 non-null   object
#  23  famrel      1044 non-null   int64
#  24  freetime    1044 non-null   int64
#  25  goout       1044 non-null   int64
#  26  Dalc        1044 non-null   int64
#  27  Walc        1044 non-null   int64
#  28  health      1044 non-null   int64
#  29  absences    1044 non-null   int64
#  30  G1          1044 non-null   int64
#  31  G2          1044 non-null   int64
#  32  G3          1044 non-null   int64
#  33  course      1044 non-null   object
# dtypes: int64(16), object(18)
# memory usage: 277.4+ KB

# %% [markdown]
# # Explore the data

# %% [markdown]
# ## Missing values
# No missing data is registred in the DataFrames

# %%
df_student.isnull().sum()
# Out:
# school        0
# sex           0
# age           0
# address       0
# famsize       0
# Pstatus       0
# Medu          0
# Fedu          0
# Mjob          0
# Fjob          0
# reason        0
# guardian      0
# traveltime    0
# studytime     0
# failures      0
# schoolsup     0
# famsup        0
# paid          0
# activities    0
# nursery       0
# higher        0
# internet      0
# romantic      0
# famrel        0
# freetime      0
# goout         0
# Dalc          0
# Walc          0
# health        0
# absences      0
# G1            0
# G2            0
# G3            0
# course        0
# dtype: int64

# %% [markdown]
# ## Summary statistics by course
# Here is an overview of the grade column statistics (for G1, G2 and G3) for each course and each feature.

# %%
summary=['min', 'max','count', 'mean']
for col in list(set(df_student.columns.values[0:30])-set(['age', 'absences'])):
    print('Grouping by ', next(x['description'] for x in json_data['data']['variables'] if x["name"] == col))
    data= df_student[[col,'G1','G2','G3','course']].groupby([col,'course']).agg(summary)
    print(data)
    print('***********************************************************************')
# Out:
# Grouping by  father's job (nominal: 'teacher', 'health' care related, civil 'services' (e.g. administrative or police), 'at_home' or 'other')
#                      G1                       G2                       G3      \
#                     min max count       mean min max count       mean min max
# Fjob     course
# at_home  math         5  18    20  11.700000   0  18    20  10.600000   0  19
#          portuguese   4  18    42  10.404762   0  18    42  10.785714   0  18
# health   math         6  17    18  11.444444   6  17    18  11.388889   7  18
#          portuguese   5  18    23  12.043478   6  18    23  12.260870   6  18
# other    math         4  19   217  10.566820   0  19   217  10.410138   0  19
#          portuguese   4  18   367  11.362398   0  19   367  11.542234   0  19
# services math         3  19   111  10.828829   0  19   111  10.882883   0  20
#          portuguese   5  19   181  11.292818   0  18   181  11.370166   0  18
# teacher  math         5  19    29  12.896552   0  19    29  12.000000   0  19
#          portuguese   0  18    36  13.055556   5  18    36  13.333333   0  19
#
#
#                     count       mean
# Fjob     course
# at_home  math          20  10.150000
#          portuguese    42  11.428571
# health   math          18  11.611111
#          portuguese    23  12.565217
# other    math         217  10.193548
#          portuguese   367  11.891008
# services math         111  10.297297
#          portuguese   181  11.629834
# teacher  math          29  11.965517
#          portuguese    36  13.583333
# ***********************************************************************
# Grouping by  father's education (numeric: 0 - none,  1 - primary education (4th grade), 2 â€“ 5th to 9th grade, 3 â€“ secondary education or 4 â€“ higher education)
#                  G1                       G2                       G3      \
#                 min max count       mean min max count       mean min max
# Fedu course
# 0    math        11  13     2  12.000000  11  15     2  13.000000  10  16
#      portuguese   8  16     7  11.428571   9  17     7  11.571429  10  18
# 1    math         5  18    82   9.731707   0  18    82   9.390244   0  18
#      portuguese   5  19   174  10.522989   0  19   174  10.695402   0  19
# 2    math         5  18   115  11.026087   0  19   115  10.878261   0  19
#      portuguese   4  18   209  11.368421   0  18   209  11.411483   0  18
# 3    math         3  19   100  10.740000   0  19   100  10.750000   0  20
#      portuguese   4  17   131  11.732824   7  18   131  11.992366   1  18
# 4    math         5  19    96  11.927083   0  19    96  11.562500   0  19
#      portuguese   0  18   128  12.296875   5  18   128  12.585938   0  19
#
#
#                 count       mean
# Fedu course
# 0    math           2  13.000000
#      portuguese     7  12.142857
# 1    math          82   9.158537
#      portuguese   174  10.936782
# 2    math         115  10.260870
#      portuguese   209  11.784689
# 3    math         100  10.660000
#      portuguese   131  12.381679
# 4    math          96  11.364583
#      portuguese   128  12.921875
# ***********************************************************************
# Grouping by  weekend alcohol consumption (numeric: from 1 - very low to 5 - very high)
#                  G1                       G2                       G3      \
#                 min max count       mean min max count       mean min max
# Walc course
# 1    math         4  19   151  11.178808   0  19   151  11.052980   0  20
#      portuguese   0  19   247  11.688259   0  19   247  11.951417   0  19
# 2    math         5  18    85  11.270588   0  18    85  10.611765   0  19
#      portuguese   4  18   150  11.746667   0  18   150  11.820000   0  18
# 3    math         3  18    80  10.937500   5  18    80  10.912500   0  18
#      portuguese   4  17   120  11.308333   0  18   120  11.500000   0  18
# 4    math         5  17    51   9.980392   0  17    51   9.764706   0  17
#      portuguese   7  17    87  10.655172   0  18    87  10.735632   0  19
# 5    math         5  18    28   9.964286   5  18    28  10.357143   0  18
#      portuguese   5  17    45  10.333333   0  18    45  10.444444   0  17
#
#
#                 count       mean
# Walc course
# 1    math         151  10.735099
#      portuguese   247  12.360324
# 2    math          85  10.082353
#      portuguese   150  12.260000
# 3    math          80  10.725000
#      portuguese   120  11.666667
# 4    math          51   9.686275
#      portuguese    87  11.034483
# 5    math          28  10.142857
#      portuguese    45  10.555556
# ***********************************************************************
# Grouping by  student's home address type (binary: 'U' - urban or 'R' - rural)
#                     G1                       G2                       G3      \
#                    min max count       mean min max count       mean min max
# address course
# R       math         3  19    88  10.477273   0  18    88   9.829545   0  19
#         portuguese   4  18   197  10.746193   0  19   197  10.888325   0  19
# U       math         4  19   307  11.032573   0  19   307  10.967427   0  20
#         portuguese   0  19   452  11.683628   0  18   452  11.867257   0  19
#
#
#                    count       mean
# address course
# R       math          88   9.511364
#         portuguese   197  11.086294
# U       math         307  10.674267
#         portuguese   452  12.263274
# ***********************************************************************
# Grouping by  extra-curricular activities (binary: yes or no)
#                        G1                       G2                       G3  \
#                       min max count       mean min max count       mean min
# activities course
# no         math         3  19   194  10.716495   0  19   194  10.520619   0
#            portuguese   0  19   334  11.185629   0  19   334  11.380240   0
# yes        math         4  19   201  11.094527   0  19   201  10.900498   0
#            portuguese   4  18   315  11.625397   0  18   315  11.771429   0
#
#
#                       max count       mean
# activities course
# no         math        19   194  10.340206
#            portuguese  19   334  11.718563
# yes        math        20   201  10.487562
#            portuguese  19   315  12.104762
# ***********************************************************************
# Grouping by  current health status (numeric: from 1 - very bad to 5 - very good)
#                    G1                       G2                       G3      \
#                   min max count       mean min max count       mean min max
# health course
# 1      math         6  19    47  11.702128   5  18    47  12.042553   0  19
#        portuguese   5  18    90  11.677778   0  18    90  11.988889   0  18
# 2      math         6  19    45  11.288889   5  19    45  11.111111   0  20
#        portuguese   5  18    78  11.602564   0  18    78  11.820513   0  19
# 3      math         5  18    91  10.604396   0  19    91  10.274725   0  19
#        portuguese   0  18   124  11.193548   0  19   124  11.491935   0  19
# 4      math         5  18    66  10.727273   0  19    66  10.378788   0  19
#        portuguese   7  19   108  11.731481   0  18   108  11.888889   0  18
# 5      math         3  19   146  10.808219   0  18   146  10.589041   0  18
#        portuguese   4  18   249  11.192771   0  18   249  11.240964   0  18
#
#
#                   count       mean
# health course
# 1      math          47  11.872340
#        portuguese    90  12.477778
# 2      math          45  10.222222
#        portuguese    78  12.192308
# 3      math          91  10.010989
#        portuguese   124  11.838710
# 4      math          66  10.106061
#        portuguese   108  12.305556
# 5      math         146  10.397260
#        portuguese   249  11.469880
# ***********************************************************************
# Grouping by  number of past class failures (numeric: n if 1<=n<3, else 4)
#                      G1                       G2                       G3      \
#                     min max count       mean min max count       mean min max
# failures course
# 0        math         5  19   312  11.467949   0  19   312  11.349359   0  20
#          portuguese   0  19   549  11.888889   0  19   549  12.102004   0  19
# 1        math         3  18    50   9.560000   0  18    50   9.260000   0  18
#          portuguese   4  14    70   8.900000   0  15    70   8.700000   0  16
# 2        math         4  15    17   8.352941   0  14    17   7.352941   0  15
#          portuguese   4  14    16   8.187500   5  15    16   8.937500   0  15
# 3        math         5  10    16   6.937500   0   9    16   6.437500   0  10
#          portuguese   6  11    14   8.357143   0  11    14   8.071429   0  11
#
#
#                     count       mean
# failures course
# 0        math         312  11.253205
#          portuguese   549  12.510018
# 1        math          50   8.120000
#          portuguese    70   8.642857
# 2        math          17   6.235294
#          portuguese    16   8.812500
# 3        math          16   5.687500
#          portuguese    14   8.071429
# ***********************************************************************
# Grouping by  extra educational support (binary: yes or no)
#                       G1                       G2                       G3  \
#                      min max count       mean min max count       mean min
# schoolsup course
# no        math         3  19   344  11.180233   0  19   344  10.883721   0
#           portuguese   4  19   581  11.466437   0  19   581  11.626506   0
# yes       math         5  16    51   9.078431   5  16    51   9.568627   0
#           portuguese   0  17    68  10.823529   6  18    68  11.088235   0
#
#
#                      max count       mean
# schoolsup course
# no        math        20   344  10.561047
#           portuguese  19   581  11.979346
# yes       math        17    51   9.431373
#           portuguese  18    68  11.279412
# ***********************************************************************
# Grouping by  home to school travel time (numeric: 1 - <15 min., 2 - 15 to 30 min., 3 - 30 min. to 1 hour, or 4 - >1 hour)
#                        G1                       G2                       G3  \
#                       min max count       mean min max count       mean min
# traveltime course
# 1          math         3  19   257  11.097276   0  19   257  11.058366   0
#            portuguese   4  18   366  11.759563   0  18   366  11.907104   0
# 2          math         4  19   107  10.644860   0  18   107  10.336449   0
#            portuguese   0  19   213  11.046948   0  19   213  11.309859   0
# 3          math         6  18    23  10.739130   0  18    23   9.565217   0
#            portuguese   6  16    54  10.648148   0  17    54  10.814815   0
# 4          math         5  11     8   8.875000   0  13     8   8.000000   0
#            portuguese   7  14    16  10.375000   8  13    16   9.875000   8
#
#
#                       max count       mean
# traveltime course
# 1          math        20   257  10.782101
#            portuguese  19   366  12.251366
# 2          math        19   107   9.906542
#            portuguese  19   213  11.577465
# 3          math        18    23   9.260870
#            portuguese  18    54  11.166667
# 4          math        13     8   8.750000
#            portuguese  16    16  10.875000
# ***********************************************************************
# Grouping by  free time after school (numeric: from 1 - very low to 5 - very high)
#                      G1                       G2                       G3      \
#                     min max count       mean min max count       mean min max
# freetime course
# 1        math         6  18    19  10.157895   5  18    19  10.421053   0  18
#          portuguese   7  18    45  11.066667   6  19    45  11.444444   7  19
# 2        math         6  19    64  12.046875   0  19    64  11.734375   0  20
#          portuguese   6  18   107  12.046729   0  18   107  12.233645   0  19
# 3        math         3  19   157  10.369427   0  18   157  10.280255   0  19
#          portuguese   0  19   251  11.509960   0  18   251  11.669323   0  18
# 4        math         5  19   115  10.834783   0  18   115  10.565217   0  19
#          portuguese   4  18   178  11.247191   0  18   178  11.410112   0  18
# 5        math         5  18    40  11.775000   0  19    40  11.350000   0  19
#          portuguese   5  18    68  10.588235   0  17    68  10.661765   0  18
#
#
#                     count       mean
# freetime course
# 1        math          19   9.842105
#          portuguese    45  11.733333
# 2        math          64  11.562500
#          portuguese   107  12.710280
# 3        math         157   9.783439
#          portuguese   251  12.059761
# 4        math         115  10.426087
#          portuguese   178  11.713483
# 5        math          40  11.300000
#          portuguese    68  10.691176
# ***********************************************************************
# Grouping by  going out with friends (numeric: from 1 - very low to 5 - very high)
#                   G1                       G2                       G3      \
#                  min max count       mean min max count       mean min max
# goout course
# 1     math         6  17    23  11.130435   5  16    23  10.782609   0  17
#       portuguese   4  15    48  10.416667   0  15    48  10.437500   0  15
# 2     math         4  19   103  11.368932   0  19   103  11.456311   0  20
#       portuguese   5  19   145  12.013793   5  19   145  12.324138   0  19
# 3     math         3  19   130  11.276923   0  19   130  11.053846   0  19
#       portuguese   6  18   205  11.634146   0  18   205  11.746341   0  18
# 4     math         5  19    86  10.430233   0  18    86  10.058140   0  19
#       portuguese   0  17   141  11.255319   0  18   141  11.524823   0  19
# 5     math         5  18    53   9.792453   0  18    53   9.471698   0  18
#       portuguese   4  18   110  10.763636   0  18   110  10.800000   0  18
#
#
#                  count       mean
# goout course
# 1     math          23   9.869565
#       portuguese    48  10.729167
# 2     math         103  11.194175
#       portuguese   145  12.668966
# 3     math         130  10.961538
#       portuguese   205  12.151220
# 4     math          86   9.651163
#       portuguese   141  11.971631
# 5     math          53   9.037736
#       portuguese   110  10.872727
# ***********************************************************************
# Grouping by  family educational support (binary: yes or no)
#                    G1                       G2                       G3      \
#                   min max count       mean min max count       mean min max
# famsup course
# no     math         5  19   153  11.261438   0  19   153  10.993464   0  20
#        portuguese   0  19   251  11.266932   0  18   251  11.430279   0  19
# yes    math         3  19   242  10.685950   0  18   242  10.537190   0  19
#        portuguese   4  18   398  11.482412   0  19   398  11.658291   0  19
#
#
#                   count       mean
# famsup course
# no     math         153  10.640523
#        portuguese   251  11.665339
# yes    math         242  10.272727
#        portuguese   398  12.057789
# ***********************************************************************
# Grouping by  extra paid classes within the course subject (Math or Portuguese) (binary: yes or no)
#                  G1                       G2                       G3      \
#                 min max count       mean min max count       mean min max
# paid course
# no   math         3  19   214  10.789720   0  19   214  10.350467   0  20
#      portuguese   0  19   610  11.442623   0  19   610  11.595082   0  19
# yes  math         6  18   181  11.049724   0  18   181  11.143646   0  19
#      portuguese   7  17    39  10.717949   7  16    39  11.179487   0  16
#
#
#                 count       mean
# paid course
# no   math         214   9.985981
#      portuguese   610  11.950820
# yes  math         181  10.922652
#      portuguese    39  11.205128
# ***********************************************************************
# Grouping by  family size (binary: 'LE3' - less or equal to 3 or 'GT3' - greater than 3)
#                     G1                       G2                       G3      \
#                    min max count       mean min max count       mean min max
# famsize course
# GT3     math         4  19   281  10.758007   0  19   281  10.519573   0  20
#         portuguese   0  18   457  11.315098   0  18   457  11.496718   0  19
# LE3     math         3  19   114  11.280702   0  19   114  11.192982   0  19
#         portuguese   5  19   192  11.598958   0  19   192  11.744792   0  19
#
#
#                    count       mean
# famsize course
# GT3     math         281  10.177936
#         portuguese   457  11.811816
# LE3     math         114  11.000000
#         portuguese   192  12.130208
# ***********************************************************************
# Grouping by  weekly study time (numeric: 1 - <2 hours, 2 - 2 to 5 hours, 3 - 5 to 10 hours, or 4 - >10 hours)
#                       G1                       G2                       G3  \
#                      min max count       mean min max count       mean min
# studytime course
# 1         math         4  18   105  10.438095   0  19   105  10.276190   0
#           portuguese   4  18   212  10.504717   0  18   212  10.702830   0
# 2         math         3  19   198  10.651515   0  18   198  10.505051   0
#           portuguese   0  18   305  11.537705   0  18   305  11.662295   0
# 3         math         6  19    65  12.046154   0  18    65  11.507692   0
#           portuguese   7  19    97  12.422680   7  18    97  12.793814   8
# 4         math         7  19    27  11.888889   7  19    27  12.037037   0
#           portuguese   5  18    35  12.771429   6  19    35  12.628571   6
#
#
#                      max count       mean
# studytime course
# 1         math        19   105  10.047619
#           portuguese  18   212  10.844340
# 2         math        19   198  10.171717
#           portuguese  19   305  12.091803
# 3         math        19    65  11.400000
#           portuguese  18    97  13.226804
# 4         math        20    27  11.259259
#           portuguese  19    35  13.057143
# ***********************************************************************
# Grouping by  reason to choose this school (nominal: close to 'home', school 'reputation', 'course' preference or 'other')
#                        G1                       G2                       G3  \
#                       min max count       mean min max count       mean min
# reason     course
# course     math         3  19   145  10.600000   0  19   145  10.172414   0
#            portuguese   0  19   285  10.982456   0  18   285  11.147368   0
# home       math         5  18   109  10.816514   0  18   109  10.743119   0
#            portuguese   5  18   149  11.657718   0  18   149  11.785235   0
# other      math         6  18    36  10.833333   5  18    36  11.222222   0
#            portuguese   5  18    72  10.694444   0  18    72  10.777778   0
# reputation math         6  19   105  11.457143   0  19   105  11.257143   0
#            portuguese   5  18   143  12.314685   0  19   143  12.587413   0
#
#
#                       max count       mean
# reason     course
# course     math        19   145   9.820690
#            portuguese  18   285  11.547368
# home       math        19   109  10.256881
#            portuguese  19   149  12.181208
# other      math        19    36  11.166667
#            portuguese  18    72  10.694444
# reputation math        20   105  11.142857
#            portuguese  19   143  12.944056
# ***********************************************************************
# Grouping by  Internet access at home (binary: yes or no)
#                      G1                       G2                       G3      \
#                     min max count       mean min max count       mean min max
# internet course
# no       math         5  18    66  10.378788   0  18    66   9.712121   0  18
#          portuguese   0  18   151  10.701987   0  19   151  10.788079   0  19
# yes      math         3  19   329  11.015198   0  19   329  10.914894   0  20
#          portuguese   4  19   498  11.610442   0  18   498  11.807229   0  19
#
#
#                     count       mean
# internet course
# no       math          66   9.409091
#          portuguese   151  11.026490
# yes      math         329  10.617021
#          portuguese   498  12.172691
# ***********************************************************************
# Grouping by  student's school (binary: 'GP' - Gabriel Pereira or 'MS' - Mousinho da Silveira)
#                    G1                       G2                       G3      \
#                   min max count       mean min max count       mean min max
# school course
# GP     math         3  19   349  10.939828   0  19   349  10.782235   0  20
#        portuguese   0  18   423  11.985816   6  19   423  12.144208   0  19
# MS     math         6  19    46  10.673913   5  18    46  10.195652   0  19
#        portuguese   4  19   226  10.300885   0  18   226  10.495575   0  19
#
#
#                   count       mean
# school course
# GP     math         349  10.489971
#        portuguese   423  12.576832
# MS     math          46   9.847826
#        portuguese   226  10.650442
# ***********************************************************************
# Grouping by  mother's education (numeric: 0 - none,  1 - primary education (4th grade), 2 - 5th to 9th grade, 3 - secondary education or 4 - higher education)
#                  G1                       G2                       G3      \
#                 min max count       mean min max count       mean min max
# Medu course
# 0    math         7  16     3  12.000000   8  15     3  12.666667   9  15
#      portuguese   9  14     6  10.833333   9  14     6  11.166667  10  15
# 1    math         5  18    59   9.745763   0  16    59   9.169492   0  16
#      portuguese   5  19   143  10.398601   0  17   143  10.524476   0  18
# 2    math         5  18   103  10.563107   0  18   103  10.359223   0  19
#      portuguese   6  18   186  11.204301   0  18   186  11.284946   0  18
# 3    math         3  18    99  10.606061   0  18    99  10.444444   0  19
#      portuguese   4  18   139  11.323741   0  19   139  11.561151   0  19
# 4    math         5  19   131  11.908397   0  19   131  11.847328   0  20
#      portuguese   0  18   175  12.502857   0  18   175  12.748571   0  19
#
#
#                 count       mean
# Medu course
# 0    math           3  13.000000
#      portuguese     6  11.666667
# 1    math          59   8.677966
#      portuguese   143  10.797203
# 2    math         103   9.728155
#      portuguese   186  11.661290
# 3    math          99  10.303030
#      portuguese   139  11.920863
# 4    math         131  11.763359
#      portuguese   175  13.068571
# ***********************************************************************
# Grouping by  student's guardian (nominal: 'mother', 'father' or 'other')
#                      G1                       G2                       G3      \
#                     min max count       mean min max count       mean min max
# guardian course
# father   math         5  19    90  11.111111   0  18    90  11.155556   0  18
#          portuguese   5  19   153  11.784314   0  18   153  11.875817   0  19
# mother   math         3  19   273  10.882784   0  19   273  10.677656   0  20
#          portuguese   0  18   455  11.389011   0  19   455  11.573626   0  19
# other    math         4  17    32  10.562500   0  18    32   9.781250   0  18
#          portuguese   7  14    41  10.073171   0  15    41  10.390244   0  15
#
#
#                     count       mean
# guardian course
# father   math          90  10.688889
#          portuguese   153  12.202614
# mother   math         273  10.483516
#          portuguese   455  11.896703
# other    math          32   9.062500
#          portuguese    41  10.902439
# ***********************************************************************
# Grouping by  wants to take higher education (binary: yes or no)
#                    G1                       G2                       G3      \
#                   min max count       mean min max count       mean min max
# higher course
# no     math         5  14    20   8.350000   0  12    20   7.800000   0  13
#        portuguese   4  14    69   8.623188   0  13    69   8.768116   0  14
# yes    math         3  19   375  11.045333   0  19   375  10.869333   0  20
#        portuguese   0  19   580  11.729310   0  19   580  11.903448   0  19
#
#
#                   count       mean
# higher course
# no     math          20   6.800000
#        portuguese    69   8.797101
# yes    math         375  10.608000
#        portuguese   580  12.275862
# ***********************************************************************
# Grouping by  workday alcohol consumption (numeric: from 1 - very low to 5 - very high)
#                  G1                       G2                       G3      \
#                 min max count       mean min max count       mean min max
# Dalc course
# 1    math         3  19   276  11.155797   0  19   276  10.949275   0  20
#      portuguese   0  19   451  11.698448   0  19   451  11.895787   0  19
# 2    math         6  18    75  10.306667   0  18    75  10.013333   0  18
#      portuguese   4  18   121  11.090909   0  18   121  11.157025   0  18
# 3    math         7  17    26  10.576923   6  17    26  10.538462   0  17
#      portuguese   8  18    43  10.441860   7  18    43  10.744186   8  18
# 4    math         6  14     9   9.777778   5  13     9   9.777778   5  13
#      portuguese   7  13    17   9.941176   0  14    17   9.470588   0  14
# 5    math         6  14     9  10.444444   7  13     9  10.777778   5  13
#      portuguese   5  16    17   9.529412   6  16    17  10.058824   5  16
#
#
#                 count       mean
# Dalc course
# 1    math         276  10.731884
#      portuguese   451  12.299335
# 2    math          75   9.253333
#      portuguese   121  11.363636
# 3    math          26  10.500000
#      portuguese    43  11.139535
# 4    math           9   9.888889
#      portuguese    17   8.941176
# 5    math           9  10.666667
#      portuguese    17  10.235294
# ***********************************************************************
# Grouping by  with a romantic relationship (binary: yes or no)
#                      G1                       G2                       G3      \
#                     min max count       mean min max count       mean min max
# romantic course
# no       math         5  19   263  10.996198   0  19   263  11.011407   0  20
#          portuguese   0  19   410  11.556098   0  19   410  11.787805   0  19
# yes      math         3  17   132  10.734848   0  18   132  10.121212   0  18
#          portuguese   5  18   239  11.129707   0  18   239  11.196653   0  18
#
#
#                     count       mean
# romantic course
# no       math         263  10.836502
#          portuguese   410  12.129268
# yes      math         132   9.575758
#          portuguese   239  11.523013
# ***********************************************************************
# Grouping by  mother's job (nominal: 'teacher', 'health' care related, civil 'services' (e.g. administrative or police), 'at_home' or 'other')
#                      G1                       G2                       G3      \
#                     min max count       mean min max count       mean min max
# Mjob     course
# at_home  math         5  18    59  10.457627   0  18    59   9.677966   0  19
#          portuguese   0  19   135  10.451852   0  18   135  10.711111   0  18
# health   math         6  19    34  12.205882   7  19    34  12.352941   0  20
#          portuguese   7  18    48  12.395833   7  18    48  12.645833   8  18
# other    math         3  19   141  10.177305   0  18   141  10.177305   0  19
#          portuguese   5  17   258  11.275194   0  18   258  11.426357   0  18
# services math         5  19   103  11.388350   0  18   103  11.213592   0  19
#          portuguese   4  18   136  11.610294   0  19   136  11.720588   0  19
# teacher  math         6  18    58  11.534483   0  19    58  11.224138   0  19
#          portuguese   5  18    72  12.555556   0  18    72  12.694444   0  19
#
#
#                     count       mean
# Mjob     course
# at_home  math          59   9.152542
#          portuguese   135  11.044444
# health   math          34  12.147059
#          portuguese    48  13.062500
# other    math         141   9.822695
#          portuguese   258  11.670543
# services math         103  11.019417
#          portuguese   136  12.147059
# teacher  math          58  11.051724
#          portuguese    72  13.138889
# ***********************************************************************
# Grouping by  attended nursery school (binary: yes or no)
#                     G1                       G2                       G3      \
#                    min max count       mean min max count       mean min max
# nursery course
# no      math         4  17    81  10.456790   0  17    81  10.209877   0  18
#         portuguese   6  18   128  11.226562   5  18   128  11.335938   0  19
# yes     math         3  19   314  11.025478   0  19   314  10.843949   0  20
#         portuguese   0  19   521  11.441459   0  19   521  11.627639   0  19
#
#
#                    count       mean
# nursery course
# no      math          81   9.950617
#         portuguese   128  11.718750
# yes     math         314  10.535032
#         portuguese   521  11.952015
# ***********************************************************************
# Grouping by  parent's cohabitation status (binary: 'T' - living together or 'A' - apart)
#                     G1                       G2                       G3      \
#                    min max count       mean min max count       mean min max
# Pstatus course
# A       math         4  18    41  11.073171   0  19    41  11.170732   0  19
#         portuguese   0  17    80  11.287500   0  18    80  11.425000   0  18
# T       math         3  19   354  10.889831   0  19   354  10.661017   0  20
#         portuguese   4  19   569  11.414763   0  19   569  11.590510   0  19
#
#
#                    count       mean
# Pstatus course
# A       math          41  11.195122
#         portuguese    80  11.912500
# T       math         354  10.324859
#         portuguese   569  11.905097
# ***********************************************************************
# Grouping by  quality of family relationships (numeric: from 1 - very bad to 5 - excellent)
#                    G1                       G2                       G3      \
#                   min max count       mean min max count       mean min max
# famrel course
# 1      math         6  16     8  10.750000   5  15     8  11.500000   0  16
#        portuguese   6  18    22  10.409091   0  18    22  10.272727   0  17
# 2      math         5  16    18  11.222222   5  16    18  11.222222   0  17
#        portuguese   4  17    29  11.034483   0  16    29  10.448276   0  16
# 3      math         6  18    68  10.558824   4  19    68  10.558824   0  19
#        portuguese   6  18   101  11.138614   0  19   101  11.207921   0  19
# 4      math         3  19   195  10.958974   0  19   195  10.676923   0  20
#        portuguese   0  18   317  11.678233   0  18   317  11.958991   0  18
# 5      math         5  19   106  11.000000   0  19   106  10.735849   0  19
#        portuguese   5  19   180  11.233333   0  18   180  11.427778   0  18
#
#
#                   count       mean
# famrel course
# 1      math           8  10.625000
#        portuguese    22  10.636364
# 2      math          18   9.888889
#        portuguese    29  10.862069
# 3      math          68  10.044118
#        portuguese   101  11.594059
# 4      math         195  10.358974
#        portuguese   317  12.343849
# 5      math         106  10.830189
#        portuguese   180  11.633333
# ***********************************************************************
# Grouping by  student's sex (binary: 'F' - female or 'M' - male)
#                 G1                       G2                       G3      \
#                min max count       mean min max count       mean min max
# sex course
# F   math         4  19   208  10.620192   0  18   208  10.389423   0  19
#     portuguese   0  19   383  11.637076   0  19   383  11.822454   0  19
# M   math         3  19   187  11.229947   0  19   187  11.074866   0  20
#     portuguese   4  18   266  11.056391   0  18   266  11.206767   0  19
#
#
#                count       mean
# sex course
# F   math         208   9.966346
#     portuguese   383  12.253264
# M   math         187  10.914439
#     portuguese   266  11.406015
# ***********************************************************************

# %% [markdown]
# We divided the age column into three intervals: 15-18, 18-20 and 20-22, then calculated the students' minimum, maximum and average scores for each course. This binning is only for statistical purposes only, the original Dataframe will retain the age values.

# %%
bins = [15, 18, 20, 22]
df=df_student.copy()
df['age_binned'] = pd.cut(df_student['age'], bins=bins,right=False,include_lowest=True,labels=['15 - 18','18 - 20','20 - 22'])
data= df[['age_binned','G1','G2','G3','course']].groupby(['age_binned','course'],observed=False).agg(summary)
print(data)
# Out:
#                        G1                       G2                       G3  \
#                       min max count       mean min max count       mean min
# age_binned course
# 15 - 18    math         4  19   284  11.010563   0  19   284  10.992958   0
#            portuguese   5  18   468  11.653846   0  19   468  11.764957   0
# 18 - 20    math         3  19   106  10.613208   0  18   106   9.933962   0
#            portuguese   0  19   172  10.796512   0  18   172  11.052326   0
# 20 - 22    math         9  17     4  12.750000   8  18     4  12.250000   7
#            portuguese   8  14     8  10.000000   9  15     8  11.750000  10
#
#
#                       max count       mean
# age_binned course
# 15 - 18    math        20   284  10.834507
#            portuguese  19   468  12.126068
# 18 - 20    math        19   106   9.245283
#            portuguese  19   172  11.354651
# 20 - 22    math        18     4  12.250000
#            portuguese  15     8  11.750000

# %% [markdown]
# A similar binning is performed on absences

# %%
bins=np.linspace(min(df["absences"]), max(df["absences"]), 4)
df['absences_binned'] = pd.cut(df['absences'], bins=bins, include_lowest=True,labels=['0 - 25','25 - 50','50 - 75'])
data= df[['absences_binned','G1','G2','G3','course']].groupby(['absences_binned','course'],observed=False).agg(summary)
print(data)
# Out:
#                              G1                          G2              \
#                             min   max count       mean  min   max count
# absences_binned course
# 0 - 25          math        3.0  19.0   387  10.937984  0.0  19.0   387
#                 portuguese  0.0  19.0   646  11.397833  0.0  19.0   646
# 25 - 50         math        7.0  13.0     5   9.200000  6.0  11.0     5
#                 portuguese  7.0  14.0     3  11.666667  8.0  15.0     3
# 50 - 75         math        9.0  11.0     3  10.000000  9.0  12.0     3
#                 portuguese  NaN   NaN     0        NaN  NaN   NaN     0
#
#                                         G3
#                                  mean  min   max count       mean
# absences_binned course
# 0 - 25          math        10.746770  0.0  20.0   387  10.449612
#                 portuguese  11.568111  0.0  19.0   646  11.902477
# 25 - 50         math         8.600000  6.0  11.0     5   8.400000
#                 portuguese  12.000000  8.0  16.0     3  12.666667
# 50 - 75         math        10.000000  8.0  11.0     3   9.333333
#                 portuguese        NaN  NaN   NaN     0        NaN

# %% [markdown]
# A high number of absences (between 50 and 75) is rare in the math course and non-existent in the Portuguese course. Absences between 25 and 50 are also infrequent in both courses.

# %% [markdown]
# ## Numeric variables
# ### Numeric data summary

# %%
num_col = df_student._get_numeric_data().columns
num_col
# Out:
# Index(['age', 'Medu', 'Fedu', 'traveltime', 'studytime', 'failures', 'famrel',
#        'freetime', 'goout', 'Dalc', 'Walc', 'health', 'absences', 'G1', 'G2',
#        'G3'],
#       dtype='object')

# %% [markdown]
# Although Medu, Fedu, traveltime, studytime, famrel, freetime, goout, Dalc, Walc and health are numeric variables, they represent categorical features. We have therefore converted them to provide consistent statistics. However, in a later step, we will convert them back to integer values, as well as other variables, so that we can apply certain predictive models that only require numerical variables.

# %%
df_student[['Medu', 'Fedu', 'traveltime', 'studytime', 'famrel','freetime', 'goout', 'Dalc', 'Walc', 'health']] = df_student[['Medu', 'Fedu', 'traveltime', 'studytime', 'famrel','freetime', 'goout', 'Dalc', 'Walc', 'health']].astype('category')
df_student.dtypes
# Out:
# school          object
# sex             object
# age              int64
# address         object
# famsize         object
# Pstatus         object
# Medu          category
# Fedu          category
# Mjob            object
# Fjob            object
# reason          object
# guardian        object
# traveltime    category
# studytime     category
# failures         int64
# schoolsup       object
# famsup          object
# paid            object
# activities      object
# nursery         object
# higher          object
# internet        object
# romantic        object
# famrel        category
# freetime      category
# goout         category
# Dalc          category
# Walc          category
# health        category
# absences         int64
# G1               int64
# G2               int64
# G3               int64
# course          object
# dtype: object

# %%
num_col = df_student._get_numeric_data().columns
df_num = df_student.loc[:,num_col]
df_num.describe().T
# Out:
#            count       mean       std   min   25%   50%   75%   max
# age       1044.0  16.726054  1.239975  15.0  16.0  17.0  18.0  22.0
# failures  1044.0   0.264368  0.656142   0.0   0.0   0.0   0.0   3.0
# absences  1044.0   4.434866  6.210017   0.0   0.0   2.0   6.0  75.0
# G1        1044.0  11.213602  2.983394   0.0   9.0  11.0  13.0  19.0
# G2        1044.0  11.246169  3.285071   0.0   9.0  11.0  13.0  19.0
# G3        1044.0  11.341954  3.864796   0.0  10.0  11.0  14.0  20.0

# %% [markdown]
# ### Distributions of feature values

# %%
df_student.loc[:,num_col].hist(figsize=(15,10))
plt.subplots_adjust(hspace=0.5);
plt.show()

# %% [markdown]
# The 'absences' feature has a long tailed distribution. To avoid skewing the data, it may be advisable to drop rows with a large number of absences. Let's count the number of students relative to the number of absences

# %%
df_student['absences'].value_counts().sort_index()
# Out:
# absences
# 0     359
# 1      15
# 2     175
# 3      15
# 4     146
# 5      17
# 6      80
# 7      10
# 8      64
# 9      10
# 10     38
# 11      8
# 12     24
# 13      4
# 14     20
# 15      5
# 16     17
# 17      1
# 18      8
# 19      1
# 20      4
# 21      3
# 22      5
# 23      1
# 24      2
# 25      1
# 26      2
# 28      1
# 30      2
# 32      1
# 38      1
# 40      1
# 54      1
# 56      1
# 75      1
# Name: count, dtype: int64

# %% [markdown]
# We can fix a threshold equal to the 98th percentile.

# %%
np.percentile(df_student['absences'], 98)
# Out:
# 21.0

# %% [markdown]
# Students with absences above 21 will be removed from the data.

# %%
df_student = df_student[df_student['absences']<=21]

# ordf_student.drop(index=list(df_student[df_student['absences']>=32].index),axis=0,inplace=True)

df_student.shape
# Out:
# (1024, 34)

# %% [markdown]
# Let's plot the new distribution of absences

# %%
fig = plt.figure(figsize=(5,3))
df_student.loc[:,'absences'].hist()
fig.suptitle('Distribution of absences');

# %% [markdown]
# ## Categorical variables

# %%
categ_col = list(set(df_student.columns)-set( num_col)) #[x for x in df_student.columns if x not in num_col] 
df_categ = df_student.loc[:,categ_col]
df_categ.describe().T
# Out:
#            count unique         top freq
# Fjob        1024      5       other  574
# Fedu        1024      5           2  319
# activities  1024      2          no  516
# health      1024      5           5  388
# schoolsup   1024      2          no  907
# traveltime  1024      4           1  613
# reason      1024      4      course  428
# course      1024      2  portuguese  643
# school      1024      2          GP  752
# Medu        1024      5           4  298
# guardian    1024      3      mother  712
# higher      1024      2         yes  937
# Dalc        1024      5           1  718
# Pstatus     1024      2           T  908
# famrel      1024      5           4  500
# nursery     1024      2         yes  820
# Walc        1024      5           1  394
# address     1024      2           U  741
# freetime    1024      5           3  401
# goout       1024      5           3  329
# famsup      1024      2         yes  627
# famsize     1024      2         GT3  724
# studytime   1024      4           2  493
# internet    1024      2         yes  808
# romantic    1024      2          no  667
# Mjob        1024      5       other  390
# paid        1024      2          no  813
# sex         1024      2           F  577

# %% [markdown]
# ## Target Feature

# %%
fig, ax = plt.subplots(1, 2,figsize=(10,4))
df_student.plot(x="G1", y="G3", kind="scatter",ax=ax[0]);
df_student.plot(x="G2", y="G3", kind="scatter",ax=ax[1]);

# %%
#%matplotlib widget
#from mpl_toolkits import mplot3d
# Creating figure
fig = plt.figure(figsize = (12, 10))
ax = plt.axes(projection ="3d")
 
# Creating plot
x = df_student['G1']
y = df_student['G2']
z = df_student['G3']
ax.scatter3D(x, y, z)
ax.set_xlabel('G1', fontweight ='bold') 
ax.set_ylabel('G2', fontweight ='bold') 
ax.set_zlabel('G3', fontweight ='bold')
fig.suptitle("Target feature G3 according to G1 and G2");

# %% [markdown]
# G3 is linearly correlated with G1 and G2. Students having poor results in G1 and G2 are likely to also have poor results in G3. We can expect that the G1 and G2 grades would have a high impact in the prediction of G3. In order not to over-bias the model with G1 and G2, we can consider different configurations in which we drop one or both of these variables. The target variable is G3, as it determines the final grade at high school.

# %% [markdown]
# We now consider the distribution of G3 according to two classification criteria:
# - Binary classification: pass if G3>=10, else fail
# - 5-level classification:
#     - excellent/very good: G3 between 16 and 20
#     - good: G3 between 14 and 15
#     - satisfactory: G3 between 12 and 13
#     - sufficient: G3 between 10 and 11
#     - fail: G3 between 0 and 9

# %%
def binary_funct(x):
    if x >= 10:
        return 'pass'
    else:
        return 'fail'

def level5_funct(x):
    if x>= 16 and x<=20:
        return 'excellent'
    elif x>=14 and x<=15:
        return 'good'
    elif x>=12 and x<= 13:
        return 'satisfactory'
    elif x>=10 and x<=11:
        return 'sufficient'
    elif x>=0 and x<=9:
        return 'fail'
    else:
        return 'not classified'

classif = df_student.copy()
classif.loc[:,'binary'] = list(map(binary_funct,df_student.loc[:,'G3']))
classif['5-level'] = list(map(level5_funct,df_student['G3']))
classif
# Out:
#      school sex  age address famsize Pstatus Medu Fedu      Mjob      Fjob  \
# 0        GP   F   18       U     GT3       A    4    4   at_home   teacher
# 1        GP   F   17       U     GT3       T    1    1   at_home     other
# 2        GP   F   15       U     LE3       T    1    1   at_home     other
# 3        GP   F   15       U     GT3       T    4    2    health  services
# 4        GP   F   16       U     GT3       T    3    3     other     other
# ...     ...  ..  ...     ...     ...     ...  ...  ...       ...       ...
# 1039     MS   F   19       R     GT3       T    2    3  services     other
# 1040     MS   F   18       U     LE3       T    3    1   teacher  services
# 1041     MS   F   18       U     GT3       T    1    1     other     other
# 1042     MS   M   17       U     LE3       T    3    1  services  services
# 1043     MS   M   18       R     LE3       T    3    2  services     other
#
#       ... Dalc Walc health absences  G1  G2  G3      course binary     5-level
# 0     ...    1    1      3        6   5   6   6        math   fail        fail
# 1     ...    1    1      3        4   5   5   6        math   fail        fail
# 2     ...    2    3      3       10   7   8  10        math   pass  sufficient
# 3     ...    1    1      5        2  15  14  15        math   pass        good
# 4     ...    1    2      5        4   6  10  10        math   pass  sufficient
# ...   ...  ...  ...    ...      ...  ..  ..  ..         ...    ...         ...
# 1039  ...    1    2      5        4  10  11  10  portuguese   pass  sufficient
# 1040  ...    1    1      1        4  15  15  16  portuguese   pass   excellent
# 1041  ...    1    1      5        6  11  12   9  portuguese   fail        fail
# 1042  ...    3    4      2        6  10  10  10  portuguese   pass  sufficient
# 1043  ...    3    4      5        4  10  11  11  portuguese   pass  sufficient
#
# [1024 rows x 36 columns]

# %% [markdown]
# Let's first plot the distribution of G3 for each course

# %%
fig, ax = plt.subplots(1, 2)
classif.loc[classif['course'] == 'math','G3'].hist(figsize=(10,4),ax=ax[0])
ax[0].set_title("Math course")
classif.loc[classif['course'] == 'portuguese','G3'].hist(figsize=(10,4),ax=ax[1])
ax[1].set_title("Portuguese course")
fig.suptitle("Distribution of G3");

# %% [markdown]
# We plot next the distribution of G3 according to the binary classification and the 5-level classification.

# %%
fig, ax = plt.subplots(1, 2,figsize=(10,4))
classif.loc[classif['course'] == 'math',:].sort_values('G3', ascending=True)['binary'].hist(density=True,ax=ax[0])
ax[0].set_title("Math course")
classif.loc[classif['course'] == 'portuguese',:].sort_values('G3', ascending=True)['binary'].hist(density=True,ax=ax[1])
ax[1].set_title("Portuguese course")
fig.suptitle("Distribution of G3 according to the binary classification");

# %% [markdown]
# The failure rate in math is higher than in Portuguese, but success rates are close.

# %%
fig, ax = plt.subplots(1, 2,figsize=(10,4))
classif.loc[classif['course'] == 'math',:].sort_values('G3', ascending=True)['5-level'].hist(density=True,ax=ax[0])
ax[0].set_title("Math course")
classif.loc[classif['course'] == 'portuguese',:].sort_values('G3', ascending=True)['5-level'].hist(density=True,ax=ax[1])
ax[1].set_title("Portuguese course")
ax[0].set_ylim(0,1)
ax[1].set_ylim(0,1)
fig.suptitle("Distribution of G3 according to the 5-level classification");

# %% [markdown]
# Results in Portuguese are more satisfactory than in mathematics.

# %%
counts
# Out:
# guardian      father  mother  other
# 5-level
# excellent         10      27      2
# fail              25      82     15
# good              14      45      1
# satisfactory      17      38      6
# sufficient        24      70      5

# %%
#filter='famrel'
#fig,axs = plt.subplots(1,2,figsize=(10,4))
#counts_math = classif[classif['course']=='math'].groupby(['5-level',filter]).size().unstack()

#counts_math.index = pd.Categorical(counts_math.index, categories=['fail','sufficient','satisfactory','good','excellent'], ordered=True)
#counts_math = counts_math.sort_index()

#counts_port = classif[classif['course']=='portuguese'].groupby(['5-level',filter]).size().unstack()

#counts_port.index = pd.Categorical(counts_port.index, categories=['fail','sufficient','satisfactory','good','excellent'], ordered=True)
#counts_port = counts_port.sort_index()

#counts_math.plot(kind='bar', stacked=True,ax=axs[0])
#counts_port.plot(kind='bar', stacked=True,ax=axs[1])
#plt.title("Distribution of schoolsup in the different classes")
#plt.show()

# %% [markdown]
# # Categorical feature encoding

# %% [markdown]
# We create an all-numeric dataFrame from df_student called df_student_numeric by encoding categorical variables.

# %%
df_student_numeric=df_student.copy()

# %% [markdown]
# ## Binary features
# we will convert yes/no variables typed as object in the current Dataframe to boolean variables

# %%
df_student_numeric[['nursery','internet','activities','romantic','higher','famsup','schoolsup','paid']] = df_student_numeric[['nursery','internet','activities','romantic','higher','famsup','schoolsup','paid']].replace({'yes':1,'no':0}) 
df_student_numeric.dtypes
# Out:
# school          object
# sex             object
# age              int64
# address         object
# famsize         object
# Pstatus         object
# Medu          category
# Fedu          category
# Mjob            object
# Fjob            object
# reason          object
# guardian        object
# traveltime    category
# studytime     category
# failures         int64
# schoolsup        int64
# famsup           int64
# paid             int64
# activities       int64
# nursery          int64
# higher           int64
# internet         int64
# romantic         int64
# famrel        category
# freetime      category
# goout         category
# Dalc          category
# Walc          category
# health        category
# absences         int64
# G1               int64
# G2               int64
# G3               int64
# course          object
# dtype: object

# %% [markdown]
# Other binary features are persent in the df_student DataFrame:
# - sex: student's sex ('F' - female or 'M' - male)
# - school: student's school ('GP' - Gabriel Pereira or 'MS' - Mousinho da Silveira)
# - address: student's home address type ('U' - urban or 'R' - rural)
# - famsize: family size ('LE3' - less or equal to 3 or 'GT3' - greater than 3)
# - Pstatus: parent's cohabitation status ('T' - living together or 'A' - apart)
# - course: course ('math' or 'portuguese')
#
# We also encoded these variables using 0/1 values

# %%
cols=["sex","address","Pstatus","famsize","school","course"]
for c in cols:
    values=df_student_numeric[c].unique()
    df_student_numeric[[c]] = df_student_numeric[[c]].replace({values[0]:1,values[1]:0})
    df_student_numeric.rename(columns={c:c+'_'+values[0]}, inplace=True)
df_student_numeric.dtypes
# Out:
# school_GP         int64
# sex_F             int64
# age               int64
# address_U         int64
# famsize_GT3       int64
# Pstatus_A         int64
# Medu           category
# Fedu           category
# Mjob             object
# Fjob             object
# reason           object
# guardian         object
# traveltime     category
# studytime      category
# failures          int64
# schoolsup         int64
# famsup            int64
# paid              int64
# activities        int64
# nursery           int64
# higher            int64
# internet          int64
# romantic          int64
# famrel         category
# freetime       category
# goout          category
# Dalc           category
# Walc           category
# health         category
# absences          int64
# G1                int64
# G2                int64
# G3                int64
# course_math       int64
# dtype: object

# %% [markdown]
# ## Ordinal features
# We re-convert category variables 'Medu', 'Fedu', 'traveltime', 'studytime', 'famrel','freetime', 'goout', 'Dalc', 'Walc', 'health' to integers. As these variables have a certain order associated with them, we simply keep the integers assigned to each variable.
# - Medu: mother's education (0 - none, 1 - primary education (4th grade), 2 - 5th to 9th grade, 3 - secondary education or 4 - higher education)
# - Fedu: father's education (0 - none, 1 - primary education (4th grade), 2 - 5th to 9th grade, 3 - secondary education or 4 - higher education)
# - traveltime: home to school travel time (1 - <15 min., 2 - 15 to 30 min., 3 - 30 min. to 1 hour, or 4 - >1 hour)
# - studytime: weekly study time (1 - <2 hours, 2 - 2 to 5 hours, 3 - 5 to 10 hours, or 4 - >10 hours)
# - famrel: quality of family relationships (from 1 - very bad to 5 - excellent)
# - freetime: free time after school (from 1 - very low to 5 - very high)
# - goout: going out with friends (from 1 - very low to 5 - very high)
# - Dalc: workday alcohol consumption (from 1 - very low to 5 - very high)
# - Walc: weekend alcohol consumption (from 1 - very low to 5 - very high)
# - health: current health status (from 1 - very bad to 5 - very good)

# %%
df_student_numeric[['Medu', 'Fedu', 'traveltime', 'studytime', 'famrel','freetime', 'goout', 'Dalc', 'Walc', 'health']] = df_student_numeric[['Medu', 'Fedu', 'traveltime', 'studytime', 'famrel','freetime', 'goout', 'Dalc', 'Walc', 'health']].astype('int')
df_student_numeric.dtypes
# Out:
# school_GP       int64
# sex_F           int64
# age             int64
# address_U       int64
# famsize_GT3     int64
# Pstatus_A       int64
# Medu            int32
# Fedu            int32
# Mjob           object
# Fjob           object
# reason         object
# guardian       object
# traveltime      int32
# studytime       int32
# failures        int64
# schoolsup       int64
# famsup          int64
# paid            int64
# activities      int64
# nursery         int64
# higher          int64
# internet        int64
# romantic        int64
# famrel          int32
# freetime        int32
# goout           int32
# Dalc            int32
# Walc            int32
# health          int32
# absences        int64
# G1              int64
# G2              int64
# G3              int64
# course_math     int64
# dtype: object

# %% [markdown]
# ## Nominal features
# We use indicator variables (also called dummy variable) to transform categorical variables into integers. Four remaining object variables should be encoded:
# - Mjob: mother's job ('teacher', 'health' care related, civil 'services' (e.g. administrative or police), 'at_home' or 'other')
# - Fjob: ather's job ('teacher', 'health' care related, civil 'services' (e.g. administrative or police), 'at_home' or 'other')
# - reason: reason to choose this school (close to 'home', school 'reputation', 'course' preference or 'other')
# - guardian: student's guardian ('mother', 'father' or 'other')

# %%
nominals=["Mjob","Fjob","reason","guardian"]
for col in nominals:
    dummy_variable = pd.get_dummies(df_student_numeric[col],prefix=col,drop_first=True)
    df_student_numeric = pd.concat([df_student_numeric, dummy_variable], axis=1)

df_student_numeric.drop(nominals, axis = 1, inplace=True)
df_student_numeric.head()
# Out:
#    school_GP  sex_F  age  address_U  famsize_GT3  Pstatus_A  Medu  Fedu  \
# 0          1      1   18          1            1          1     4     4
# 1          1      1   17          1            1          0     1     1
# 2          1      1   15          1            0          0     1     1
# 3          1      1   15          1            1          0     4     2
# 4          1      1   16          1            1          0     3     3
#
#    traveltime  studytime  ...  Mjob_teacher  Fjob_health  Fjob_other  \
# 0           2          2  ...         False        False       False
# 1           1          2  ...         False        False        True
# 2           1          2  ...         False        False        True
# 3           1          3  ...         False        False       False
# 4           1          2  ...         False        False        True
#
#    Fjob_services  Fjob_teacher  reason_home  reason_other  reason_reputation  \
# 0          False          True        False         False              False
# 1          False         False        False         False              False
# 2          False         False        False          True              False
# 3           True         False         True         False              False
# 4          False         False         True         False              False
#
#    guardian_mother  guardian_other
# 0             True           False
# 1            False           False
# 2             True           False
# 3             True           False
# 4            False           False
#
# [5 rows x 43 columns]

# %%
df_student_numeric.dtypes
# Out:
# school_GP            int64
# sex_F                int64
# age                  int64
# address_U            int64
# famsize_GT3          int64
# Pstatus_A            int64
# Medu                 int32
# Fedu                 int32
# traveltime           int32
# studytime            int32
# failures             int64
# schoolsup            int64
# famsup               int64
# paid                 int64
# activities           int64
# nursery              int64
# higher               int64
# internet             int64
# romantic             int64
# famrel               int32
# freetime             int32
# goout                int32
# Dalc                 int32
# Walc                 int32
# health               int32
# absences             int64
# G1                   int64
# G2                   int64
# G3                   int64
# course_math          int64
# Mjob_health           bool
# Mjob_other            bool
# Mjob_services         bool
# Mjob_teacher          bool
# Fjob_health           bool
# Fjob_other            bool
# Fjob_services         bool
# Fjob_teacher          bool
# reason_home           bool
# reason_other          bool
# reason_reputation     bool
# guardian_mother       bool
# guardian_other        bool
# dtype: object

# %% [markdown]
# # Save the new DataFrames

# %%
# save the data to a new csv file
df_student.to_csv('./data/data_student_cleaned.csv',index=False)

# %%
# save the all-numeric data to a csv file
df_student_numeric.to_csv('./data/data_student_numeric.csv',index=False)
